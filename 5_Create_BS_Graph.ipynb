# %% [markdown]
# ## Create Balance Sheet Graph

# %% [markdown]
# Objectives:
# - Read SQL Database
# - Create list to loop
# - Create a graph from available tickers

# %%
# Imports
import pandas as pd
import plotly.graph_objects as go

# Display pandas dataframes in full form
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
# Import SQLite3 table
sqlite_table = "balance_sheet" 
table = pd.read_sql(sqlite_table, 'sqlite:///financialmodelingprep.db')
print(len(table))
table.head()
# Out:
# 57876
#         date    symbol reportedCurrency   cik fillingDate acceptedDate  \
# 0 2020-12-31  ALMIL.PA              EUR  None  2020-12-31   2020-12-31
# 1 2019-12-31  ALMIL.PA              EUR  None  2019-12-31   2019-12-31
# 2 2018-12-31  ALMIL.PA              EUR  None  2018-12-31   2018-12-31
# 3 2017-12-31  ALMIL.PA              EUR  None  2017-12-31   2017-12-31
# 4 2016-12-31  ALMIL.PA              EUR  None  2016-12-31   2016-12-31
#
#   calendarYear period  cashAndCashEquivalents  shortTermInvestments  \
# 0         2020     FY              19885000.0                   0.0
# 1         2019     FY              13760000.0                   0.0
# 2         2018     FY               9552000.0             9074000.0
# 3         2017     FY              23385000.0             9074000.0
# 4         2016     FY              28129000.0             9070000.0
#
#    cashAndShortTermInvestments  netReceivables  inventory  otherCurrentAssets  \
# 0                     19885000             0.0        0.0            39847000
# 1                     13760000             0.0        0.0            40052000
# 2                     18626000             0.0        0.0            36669000
# 3                     32459000             0.0        0.0            26970000
# 4                     37199000             0.0        0.0            22462000
#
#    totalCurrentAssets  propertyPlantEquipmentNet   goodwill  intangibleAssets  \
# 0            59732000                 29879000.0   419000.0         3488000.0
# 1            53812000                 31201918.0  1018000.0         4075749.0
# 2            55295000                 32712066.0  1674086.0         7255369.0
# 3            59429000                 33346987.0  2329348.0         3036105.0
# 4            59661000                 33831833.0  2984610.0         2587191.0
#
#    goodwillAndIntangibleAssets  longTermInvestments  taxAssets  \
# 0                    3907000.0                  0.0        0.0
# 1                    5093749.0                  0.0        0.0
# 2                    8929455.0           -7634682.0        0.0
# 3                    5365453.0           -7667221.0        0.0
# 4                    5571801.0           -7891419.0        0.0
#
#    otherNonCurrentAssets  totalNonCurrentAssets  otherAssets  totalAssets  \
# 0              1734000.0             35520000.0          0.0     95252000
# 1              2093333.0             38389000.0          0.0     92200000
# 2              6064161.0             40071000.0          0.0     95365000
# 3              9701781.0             40747000.0          0.0    100176000
# 4              9542785.0             41055000.0          0.0    100716000
#
#    accountPayables  shortTermDebt  taxPayables  deferredRevenue  \
# 0       14740000.0         3000.0    8986000.0              0.0
# 1       10857000.0      1606384.0    9700424.0              0.0
# 2       12411440.0      1531686.0    7730942.0              0.0
# 3       12144284.0      1487829.0    6358740.0              0.0
# 4        9718328.0         2539.0    5407439.0              0.0
#
#    otherCurrentLiabilities  totalCurrentLiabilities  longTermDebt  \
# 0               23450000.0                 38193000    16878000.0
# 1               15468003.0                 27931387    16120162.0
# 2               15580112.0                 29523238    17698034.0
# 3               12027406.0                 25659519    19228400.0
# 4               12129707.0                 21850574    22229592.0
#
#    deferredRevenueNonCurrent  deferredTaxLiabilitiesNonCurrent  \
# 0                        0.0                           86000.0
# 1                        0.0                           49000.0
# 2                        0.0                               0.0
# 3                        0.0                               0.0
# 4                        0.0                               0.0
#
#    otherNonCurrentLiabilities  totalNonCurrentLiabilities  otherLiabilities  \
# 0                    405000.0                  17369000.0               0.0
# 1                      -549.0                  16168613.0               0.0
# 2                      7728.0                  17705762.0               0.0
# 3                     40081.0                  19268481.0               0.0
# 4                      1834.0                  22231426.0               0.0
#
#    capitalLeaseObligations  totalLiabilities  preferredStock  commonStock  \
# 0                      0.0          55562000             0.0     264000.0
# 1                      0.0          44100000             0.0     290000.0
# 2                      0.0          47229000             0.0     289000.0
# 3                      0.0          44928000             0.0     312000.0
# 4                      0.0          44082000             0.0     311000.0
#
#    retainedEarnings  accumulatedOtherComprehensiveIncomeLoss  \
# 0        -6796000.0                              -14352000.0
# 1         2502000.0                              -12444947.0
# 2         4239000.0                              -10365033.0
# 3         5280000.0                               -8280534.0
# 4         6109000.0                               -6486243.0
#
#    othertotalStockholdersEquity  totalStockholdersEquity  \
# 0                    60574000.0                 39690000
# 1                    57752947.0                 48100000
# 2                    53973033.0                 48136000
# 3                    57936534.0                 55248000
# 4                    56700243.0                 56634000
#
#    totalLiabilitiesAndStockholdersEquity  minorityInterest  totalEquity  \
# 0                               95252000                 0     39690000
# 1                               92200000                 0     48100000
# 2                               95365000                 0     48136000
# 3                              100176000                 0     55248000
# 4                              100716000                 0     56634000
#
#    totalLiabilitiesAndTotalEquity  totalInvestments   totalDebt    netDebt  \
# 0                        95252000         1157000.0  16881000.0 -3004000.0
# 1                        92200000         1437250.0  17726546.0  3966546.0
# 2                        95365000         1439318.0  19229720.0  9677720.0
# 3                       100176000         1406779.0  20716229.0 -2668771.0
# 4                       100716000         1178581.0  22232131.0 -5896869.0
#
#                                                 link  \
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
# 2  https://www.infogreffe.com/recherche-entrepris...
# 3  https://www.infogreffe.com/recherche-entrepris...
# 4  https://www.infogreffe.com/recherche-entrepris...
#
#                                            finalLink
# 0  https://www.infogreffe.com/recherche-entrepris...
# 1  https://www.infogreffe.com/recherche-entrepris...
# 2  https://www.infogreffe.com/recherche-entrepris...
# 3  https://www.infogreffe.com/recherche-entrepris...
# 4  https://www.infogreffe.com/recherche-entrepris...

# %%
# Create a list to loop over

# Get the unique values
symbol_table = table.symbol.unique()
# Create a list from unique values
symbol_list = symbol_table.tolist()

# %%
# Creating a new  Dataframe for the Graphs: graph_df

# Copy original dataframe
graph_df = table.copy(deep=True)

# Add percentage columns
graph_df['tot_liability_perc'] = round(((graph_df['totalLiabilities']/graph_df['totalAssets'])*100), 0)
graph_df['tot_intang_equity_perc'] = round(((graph_df['goodwillAndIntangibleAssets']/graph_df['totalAssets'])*100), 0)
graph_df['tot_equity_perc'] = round(((graph_df['totalStockholdersEquity']/graph_df['totalAssets'])*100), 0)

# Sort the data years in ascending order
graph_df.sort_index(ascending=False, inplace=True)

graph_df.head()
# Out:
#             date   symbol reportedCurrency   cik fillingDate acceptedDate  \
# 57875 2019-12-31   HAG.DE              EUR  None  2019-12-31   2019-12-31
# 57874 2020-12-31   HAG.DE              EUR  None  2020-12-31   2020-12-31
# 57873 2005-12-31  HABA.DE              EUR  None  2005-12-31   2005-12-31
# 57872 2006-12-31  HABA.DE              EUR  None  2006-12-31   2006-12-31
# 57871 2007-12-31  HABA.DE              EUR  None  2007-12-31   2007-12-31
#
#       calendarYear period  cashAndCashEquivalents  shortTermInvestments  \
# 57875         2019     FY             137400000.0             3600000.0
# 57874         2020     FY             645500000.0            12300000.0
# 57873         2005     FY               5586600.0                   0.0
# 57872         2006     FY               4179400.0                   0.0
# 57871         2007     FY               6442300.0                   0.0
#
#        cashAndShortTermInvestments  netReceivables    inventory  \
# 57875                    141000000             0.0  411100000.0
# 57874                    657800000             0.0  403700000.0
# 57873                      5586600             0.0          0.0
# 57872                      4179400             0.0          0.0
# 57871                      6442300             0.0          0.0
#
#        otherCurrentAssets  totalCurrentAssets  propertyPlantEquipmentNet  \
# 57875           511000000          1063100000                247600000.0
# 57874           572700000          1634200000                246600000.0
# 57873             2988800             8575400                   187500.0
# 57872            12206700            16386100                   190200.0
# 57871            20779400            27221700                   174300.0
#
#           goodwill  intangibleAssets  goodwillAndIntangibleAssets  \
# 57875  637200000.0       403200000.0                 1.040400e+09
# 57874  637200000.0       386100000.0                 1.023300e+09
# 57873          0.0               0.0                 8.800000e+03
# 57872          0.0               0.0                 1.800000e+04
# 57871          0.0               0.0                 2.150000e+04
#
#        longTermInvestments   taxAssets  otherNonCurrentAssets  \
# 57875           14100000.0  30400000.0             60100000.0
# 57874            -300000.0  26300000.0             17500000.0
# 57873                  0.0         0.0            159012200.0
# 57872                  0.0         0.0            162338100.0
# 57871                  0.0         0.0            202855300.0
#
#        totalNonCurrentAssets  otherAssets  totalAssets  accountPayables  \
# 57875           1.392600e+09          0.0   2455700000      168800000.0
# 57874           1.313400e+09          0.0   2947600000      164000000.0
# 57873           1.592085e+08          0.0    167783900              0.0
# 57872           1.625463e+08          0.0    178932400              0.0
# 57871           2.030511e+08   59924200.0    290197000       18136900.0
#
#        shortTermDebt  taxPayables  deferredRevenue  otherCurrentLiabilities  \
# 57875     13000000.0   23800000.0              0.0             6.012000e+08
# 57874     13700000.0   44800000.0              0.0             1.166000e+09
# 57873      1620000.0          0.0              0.0             1.600500e+06
# 57872      1280000.0          0.0              0.0             3.281800e+06
# 57871     36397300.0          0.0              0.0             2.318000e+06
#
#        totalCurrentLiabilities  longTermDebt  deferredRevenueNonCurrent  \
# 57875                783000000   147500000.0                 16300000.0
# 57874               1343700000   140300000.0                 16000000.0
# 57873                  3220500           0.0                        0.0
# 57872                  4561800           0.0                        0.0
# 57871                 56852200    47829300.0                        0.0
#
#        deferredTaxLiabilitiesNonCurrent  otherNonCurrentLiabilities  \
# 57875                        44800000.0                1.309300e+09
# 57874                         7700000.0                1.093100e+09
# 57873                               0.0                3.770710e+07
# 57872                               0.0                3.814500e+07
# 57871                               0.0                3.000900e+07
#
#        totalNonCurrentLiabilities  otherLiabilities  capitalLeaseObligations  \
# 57875                1.517900e+09               0.0              160500000.0
# 57874                1.257100e+09               0.0              154000000.0
# 57873                3.770710e+07               0.0                      0.0
# 57872                3.814500e+07               0.0                      0.0
# 57871                7.783830e+07               0.0                      0.0
#
#        totalLiabilities  preferredStock  commonStock  retainedEarnings  \
# 57875        2300900000             0.0   10000000.0      -215800000.0
# 57874        2600800000             0.0  105000000.0      -281600000.0
# 57873          40927600             0.0          0.0               0.0
# 57872          42706800             0.0          0.0               0.0
# 57871         134690500             0.0          0.0               0.0
#
#        accumulatedOtherComprehensiveIncomeLoss  othertotalStockholdersEquity  \
# 57875                                      0.0                   347000000.0
# 57874                                      0.0                   510500000.0
# 57873                                      0.0                           0.0
# 57872                                      0.0                           0.0
# 57871                                      0.0                           0.0
#
#        totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# 57875                141200000                             2442100000
# 57874                333900000                             2934700000
# 57873                126856300                              167783900
# 57872                136225600                              178932400
# 57871                155506500                              290197000
#
#        minorityInterest  totalEquity  totalLiabilitiesAndTotalEquity  \
# 57875          13600000    154800000                      2455700000
# 57874          12900000    346800000                      2947600000
# 57873                 0    126856300                       167783900
# 57872                 0    136225600                       178932400
# 57871                 0    155506500                       290197000
#
#        totalInvestments    totalDebt      netDebt  \
# 57875        17700000.0  160500000.0   23100000.0
# 57874        12000000.0  154000000.0 -491500000.0
# 57873               0.0    1620000.0   -3966600.0
# 57872               0.0    1280000.0   -2899400.0
# 57871               0.0   84226600.0   77784300.0
#
#                                                     link  \
# 57875  https://www.bundesanzeiger.de/pub/de/suche;www...
# 57874  https://www.bundesanzeiger.de/pub/de/suche;www...
# 57873  https://www.bundesanzeiger.de/pub/de/suche;www...
# 57872  https://www.bundesanzeiger.de/pub/de/suche;www...
# 57871  https://www.bundesanzeiger.de/pub/de/suche;www...
#
#                                                finalLink  tot_liability_perc  \
# 57875  https://www.bundesanzeiger.de/pub/de/suche;www...                94.0
# 57874  https://www.bundesanzeiger.de/pub/de/suche;www...                88.0
# 57873  https://www.bundesanzeiger.de/pub/de/suche;www...                24.0
# 57872  https://www.bundesanzeiger.de/pub/de/suche;www...                24.0
# 57871  https://www.bundesanzeiger.de/pub/de/suche;www...                46.0
#
#        tot_intang_equity_perc  tot_equity_perc
# 57875                    42.0              6.0
# 57874                    35.0             11.0
# 57873                     0.0             76.0
# 57872                     0.0             76.0
# 57871                     0.0             54.0

# %%
# For Loop
years = 5
for ticker in symbol_list:
    # Get the company ticker
    company_name = ticker
    # Create new dataframe: Filter for the company ticker
    graph_df_x = graph_df[graph_df['symbol'] == ticker]
    # Get the defined amount of years
    graph_df_x = graph_df_x.iloc[-years:]
    # Get the currency of the company
    currency = graph_df_x.iloc[0]['reportedCurrency']
    # Graph th Balance Sheet
    fig = go.Figure(data=[
                          go.Bar(name='Assets',
                                 x=graph_df_x["calendarYear"],
                                 y=graph_df_x['totalAssets'],
                                 marker_color='#003B73',
                                 offsetgroup=0,
                                 ),
                          go.Bar(name='Equity',
                                 x=graph_df_x["calendarYear"],
                                 y=graph_df_x['totalStockholdersEquity'],
                                 marker_color='#01949a',
                                 offsetgroup=1,
                                 ),
                          go.Bar(name='Liabilities',
                                 x=graph_df_x["calendarYear"],
                                 y=graph_df_x['totalLiabilities'],
                                 marker_color='#db1f48',
                                 offsetgroup=1,
                                 base=graph_df_x['totalStockholdersEquity']
                                 ),
                          go.Bar(name='GW & Intangibles',
                                 x=graph_df_x["calendarYear"],
                                 y=graph_df_x['goodwillAndIntangibleAssets'],
                                 marker_color='#746C70',
                                 offsetgroup=2,
                                 )
                        ])

    fig.update_layout(barmode='group',  # group or stack
                      title=str('Balance Sheet for: '+company_name),
                      xaxis_title='Year',
                      yaxis_title=('Amount $ '+currency),
                      legend=dict(orientation="h",
                                  yanchor="bottom",
                                  xanchor="right",
                                  x=1,
                                  y=1.0),
                                  width=800, height=400
                                  )
    fig.update_traces(texttemplate='%{y:.2s}', textposition='inside')
    #fig.show()
    file_name = ("output/"+company_name+"_BS.png")
    fig.write_image(file_name, scale=2)
